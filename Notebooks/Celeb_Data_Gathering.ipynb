# %% [markdown]
# **By: Jacob van Steyn, ...**

# %% [markdown]
# # DS3010 Project : Twitter political analysis

# %%
# %%capture
# !pip install tweepy pymongo alive-progress pandas matplotlib python-dotenv

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# VARIABLES
SHOULD_CLEAR_DB = False
SHOULD_SCRAPE = False

# %%
#----------------------------------------------
# Using dotenv (loads from a file called '.env') to keep secrets safe
load_dotenv("/content/drive/MyDrive/DS 3010 - Group Project/.env")
MONGO_USERNAME = os.getenv("MONGO_USERNAME")
MONGO_PASSWORD = os.getenv("MONGO_PASSWORD")
MONGO_URL = os.getenv("MONGO_URL")

client = pymongo.MongoClient(f"mongodb+srv://{MONGO_USERNAME}:{MONGO_PASSWORD}@{MONGO_URL}/?retryWrites=true&w=majority")

dblist = client.list_database_names()
if "DS3010" in dblist:
    print("The database already exists!")
else:
    print("Database was created.")

#dblist = client.list_database_names()
#if "DS3010" in dblist:
#    print("The database already exists!")
#else:
#   print("Database was created.")

# As mongodb won't create the database until a document is created, let's insert & delete a fake one!
db = client.DS3010
celeb_tweets = db.celeb_tweets

if SHOULD_CLEAR_DB:
  document = celeb_tweets.insert_one({"test":"temp document!"})
  print(f"Num Tweets Stored: {celeb_tweets.count_documents({})}")


  # Clear DB
  celeb_tweets.delete_many({})
  print(f"Num Tweets Stored: {celeb_tweets.count_documents({})}")

# %%
#----------------------------------------------
import json
import time
import re

import tweepy
from alive_progress import alive_bar
import pandas as pd
import matplotlib.pyplot as plt


# Initialize our tweepy client
def setup():
    # Twitter API key and secret
    
    consumer_key = os.getenv("TWITTER_CONSUMER_KEY")
    consumer_secret = os.getenv("TWITTER_CONSUMER_SECRET")
    
    # Handling authentication with Twitter
    auth = tweepy.AppAuthHandler(consumer_key, consumer_secret)
    # Create a wrapper for the Twitter API
    api = tweepy.API(auth, wait_on_rate_limit=True)
    return api
    
# Helper function for handling handling rate limits and getting each page of results
    # Use alive_bar to display a progress bar as tweets are fetched
def limit_handler(cursor, total):
    with alive_bar(total, force_tty=True) as bar:
        while True:
            try:
                yield cursor.next()
                bar()
            except StopIteration:
                if (bar.current != total):
                    print(f"[Stopped!] Found {bar.current} tweets for specifed term!")
                break
                
api = setup()
# Out:
# ---------------------------------------------------------------------------
# TweepError                                Traceback (most recent call last)
# <ipython-input-9-a95f40cf309e> in <module>
#      36                 break
#      37
# ---> 38 api = setup()
#
# <ipython-input-9-a95f40cf309e> in setup()
#      18
#      19     # Handling authentication with Twitter
# ---> 20     auth = tweepy.AppAuthHandler(consumer_key, consumer_secret)
#      21     # Create a wrapper for the Twitter API
#      22     api = tweepy.API(auth, wait_on_rate_limit=True)
#
# /usr/local/lib/python3.8/dist-packages/tweepy/auth.py in __init__(self, consumer_key, consumer_secret)
#     173         data = resp.json()
#     174         if data.get('token_type') != 'bearer':
# --> 175             raise TweepError('Expected token_type to equal "bearer", '
#     176                              'but got %s instead' % data.get('token_type'))
#     177
#
# TweepError: Expected token_type to equal "bearer", but got None instead

# %%
# Read accounts from CSV
import csv

user_map = {}
with open("/content/drive/MyDrive/DS 3010 - Group Project/accounts.csv", "r") as file:
  # reading the CSV file
  csvFile = csv.reader(file)
 
  # displaying the contents of the CSV file
  for lines in csvFile:
        if lines[0] and lines[1]:
          user_map[lines[0][1:]] = lines[1] == "D"

print(len(user_map))
# Out:
# 390

# %%
from tweepy.parsers import TweepError
# Search term (omitting retweets)
count = 270

print("Setup! Retrieving Tweets now...")

# Search for tweets using Tweepy 
# Have first 45

deleted_users = []

if SHOULD_SCRAPE:
  for i, (user, val) in enumerate(user_map.items()):
    print(f"User: {user}, Index: {i}, isDem? {val}")
    search = limit_handler(tweepy.Cursor(api.user_timeline,
                            screen_name=user,
                            exclude_replies=True,
                            include_rts=False,
                            count=90).items(count), count)
    
    returned_tweets = []
    try: 
      for result in search:
          returned_tweets.append(result._json)

      if val:
        print(f"Inserting Tweets to MongoDB...\nCurrent # Dem Tweets Stored: {celeb_tweets.count_documents({})}")
        celeb_tweets.insert_many(returned_tweets)
        print(f"New Celeb Tweets Stored: {celeb_tweets.count_documents({})}")
    except TweepError:
      deleted_users.append(user)
      print("USER NOT FOUND!")
      continue
else:
  print("Not Scraping!")
  
  

# Process the results from the search using Tweepy
# Out:
# Setup! Retrieving Tweets now...
# User: BarackObama, Index: 0, isDem? True
# |████████████████████████████████████████| 270/270 [100%] in 2.4s (101.54/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 0
# New Dem Tweets Stored: 270
# User: realDonaldTrump, Index: 1, isDem? False
# |████████████████████████████████████████| 270/270 [100%] in 1.5s (165.20/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 0
# New Dem Tweets Stored: 270
# User: SpeakerPelosi, Index: 2, isDem? True
# |████████████████████████████████████████| 270/270 [100%] in 1.3s (200.00/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 270
# New Dem Tweets Stored: 540
# User: RepAndyBiggsAZ, Index: 3, isDem? False
# |████████████████████████████████████████| 270/270 [100%] in 2.0s (138.94/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 270
# New Dem Tweets Stored: 540
# User: RepGusBilirakis, Index: 4, isDem? False
# |████████████████████████████████████████| 270/270 [100%] in 1.2s (241.64/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 540
# New Dem Tweets Stored: 810
# User: RepDanBishop, Index: 5, isDem? False
# |████████████████████████████████████████| 270/270 [100%] in 2.5s (102.38/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 810
# New Dem Tweets Stored: 1080
# User: SanfordBishop, Index: 6, isDem? True
# |████████████████████████████████████████| 270/270 [100%] in 1.1s (225.44/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 540
# New Dem Tweets Stored: 810
# User: repblumenauer, Index: 7, isDem? True
# |████████████████████████████████████████| 270/270 [100%] in 1.5s (178.15/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 810
# New Dem Tweets Stored: 1080
# User: RepLBR, Index: 8, isDem? True
# |████████████████████████████████████████| 270/270 [100%] in 1.8s (152.64/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 1080
# New Dem Tweets Stored: 1350
# User: RepBoebert, Index: 9, isDem? False
# |████████████████████████████████████████| 270/270 [100%] in 1.3s (201.04/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 1080
# New Dem Tweets Stored: 1350
# User: RepBonamici, Index: 10, isDem? True
# |████████████████████████████████████████| 270/270 [100%] in 2.1s (127.02/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 1350
# New Dem Tweets Stored: 1620
# User: RepBost, Index: 11, isDem? False
# |████████████████████████████████████████| 270/270 [100%] in 1.5s (195.62/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 1350
# New Dem Tweets Stored: 1620
# User: RepBowman, Index: 12, isDem? True
# |████████████████████████████████████████| 270/270 [100%] in 1.0s (230.29/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 1620
# New Dem Tweets Stored: 1890
# User: CongBoyle, Index: 13, isDem? True
# |████████████████████████████████████████| 270/270 [100%] in 1.4s (167.22/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 1890
# New Dem Tweets Stored: 2160
# User: RepBrecheen, Index: 14, isDem? False
# on 73: [Stopped!] Found 73 tweets for specifed term!
# |██████████▉⚠︎                            | (!) 73/270 [27%] in 0.5s (174.93/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 1620
# New Dem Tweets Stored: 1693
# User: RepShontelBrown, Index: 15, isDem? True
# |████████████████████████████████████████| 270/270 [100%] in 1.1s (216.67/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 2160
# New Dem Tweets Stored: 2430
# User: RepBrownley, Index: 16, isDem? True
# |████████████████████████████████████████| 270/270 [100%] in 2.1s (128.40/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 2430
# New Dem Tweets Stored: 2700
# User: VernBuchanan, Index: 17, isDem? False
# |████████████████████████████████████████| 270/270 [100%] in 1.3s (183.75/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 1693
# New Dem Tweets Stored: 1963
# User: RepKenBuck, Index: 18, isDem? False
# |████████████████████████████████████████| 270/270 [100%] in 1.6s (165.84/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 1963
# New Dem Tweets Stored: 2233
# User: RepLarryBucshon, Index: 19, isDem? False
# |████████████████████████████████████████| 270/270 [100%] in 1.1s (236.12/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 2233
# New Dem Tweets Stored: 2503
# User: RepNikkiB, Index: 20, isDem? True
# on 67: [Stopped!] Found 67 tweets for specifed term!
# |█████████▉⚠︎                             | (!) 67/270 [25%] in 0.3s (218.39/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 2700
# New Dem Tweets Stored: 2767
# User: RepTimBurchett, Index: 21, isDem? False
# |████████████████████████████████████████| 270/270 [100%] in 1.3s (201.92/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 2503
# New Dem Tweets Stored: 2773
# User: michaelcburgess, Index: 22, isDem? False
# |████████████████████████████████████████| 270/270 [100%] in 1.3s (213.46/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 2773
# New Dem Tweets Stored: 3043
# User: RepEricBurlison, Index: 23, isDem? False
# on 97: [Stopped!] Found 97 tweets for specifed term!
# |██████████████▍⚠︎                        | (!) 97/270 [36%] in 0.6s (161.81/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 3043
# New Dem Tweets Stored: 3140
# User: RepCori, Index: 24, isDem? True
# |████████████████████████████████████████| 270/270 [100%] in 1.6s (170.82/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 2767
# New Dem Tweets Stored: 3037
# User: KenCalvert, Index: 25, isDem? False
# |████████████████████████████████████████| 270/270 [100%] in 1.7s (156.41/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 3140
# New Dem Tweets Stored: 3410
# User: RepKatCammack, Index: 26, isDem? False
# |████████████████████████████████████████| 270/270 [100%] in 1.4s (175.19/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 3410
# New Dem Tweets Stored: 3680
# User: RepCarbajal, Index: 27, isDem? True
# |████████████████████████████████████████| 270/270 [100%] in 2.0s (139.04/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 3037
# New Dem Tweets Stored: 3307
# User: RepCardenas, Index: 28, isDem? True
# |████████████████████████████████████████| 270/270 [100%] in 1.2s (205.82/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 3307
# New Dem Tweets Stored: 3577
# User: RepMikeCarey, Index: 29, isDem? False
# |████████████████████████████████████████| 270/270 [100%] in 1.5s (185.11/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 3680
# New Dem Tweets Stored: 3950
# User: RepJerryCarl, Index: 30, isDem? False
# |████████████████████████████████████████| 270/270 [100%] in 1.6s (172.41/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 3950
# New Dem Tweets Stored: 4220
# User: RepAndreCarson, Index: 31, isDem? True
# |████████████████████████████████████████| 270/270 [100%] in 1.5s (167.09/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 3577
# New Dem Tweets Stored: 3847
# User: RepBuddyCarter, Index: 32, isDem? False
# |████████████████████████████████████████| 270/270 [100%] in 1.6s (160.32/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 4220
# New Dem Tweets Stored: 4490
# User: JudgeCarter, Index: 33, isDem? False
# |████████████████████████████████████████| 270/270 [100%] in 1.0s (263.43/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 4490
# New Dem Tweets Stored: 4760
# User: RepTroyCarter, Index: 34, isDem? True
# |████████████████████████████████████████| 270/270 [100%] in 1.6s (147.95/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 3847
# New Dem Tweets Stored: 4117
# User: RepCartwright, Index: 35, isDem? True
# |████████████████████████████████████████| 270/270 [100%] in 1.2s (208.29/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 4117
# New Dem Tweets Stored: 4387
# User: RepCasar, Index: 36, isDem? True
# on 57: [Stopped!] Found 57 tweets for specifed term!
# |████████▌⚠︎                              | (!) 57/270 [21%] in 0.7s (92.26/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 4387
# New Dem Tweets Stored: 4444
# User: RepEdCase, Index: 37, isDem? True
# |████████████████████████████████████████| 270/270 [100%] in 1.8s (147.10/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 4444
# New Dem Tweets Stored: 4714
# User: RepCasten, Index: 38, isDem? True
# |████████████████████████████████████████| 270/270 [100%] in 1.5s (182.34/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 4714
# New Dem Tweets Stored: 4984
# User: USRepKCastor, Index: 39, isDem? True
# |████████████████████████████████████████| 270/270 [100%] in 2.1s (134.05/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 4984
# New Dem Tweets Stored: 5254
# User: JoaquinCastrotx, Index: 40, isDem? True
# |████████████████████████████████████████| 270/270 [100%] in 3.4s (79.00/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 5254
# New Dem Tweets Stored: 5524
# User: CongresswomanSC, Index: 41, isDem? True
# |████████████████████████████████████████| 270/270 [100%] in 1.3s (197.12/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 5524
# New Dem Tweets Stored: 5794
# User: RepJudyChu, Index: 42, isDem? True
# |████████████████████████████████████████| 270/270 [100%] in 1.5s (176.49/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 5794
# New Dem Tweets Stored: 6064
# User: RepCicilline, Index: 43, isDem? True
# |████████████████████████████████████████| 270/270 [100%] in 1.7s (170.65/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 6064
# New Dem Tweets Stored: 6334
# User: RepCiscomani, Index: 44, isDem? False
# on 136: [Stopped!] Found 136 tweets for specifed term!
# |████████████████████▏⚠︎                  | (!) 136/270 [50%] in 0.7s (199.95/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 4760
# New Dem Tweets Stored: 4896
# User: RepKClark, Index: 45, isDem? True
# |⚠︎                                       | (!) 0/270 [0%] in 0.2s (0.00/s)
# USER NOT FOUND!
# User: RepYvetteClarke, Index: 46, isDem? True
# |████████████████████████████████████████| 270/270 [100%] in 2.2s (117.81/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 6334
# New Dem Tweets Stored: 6604
# User: repcleaver, Index: 47, isDem? True
# |████████████████████████████████████████| 270/270 [100%] in 1.6s (152.60/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 6604
# New Dem Tweets Stored: 6874
# User: RepBenCline, Index: 48, isDem? False
# |████████████████████████████████████████| 270/270 [100%] in 1.3s (183.47/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 4896
# New Dem Tweets Stored: 5166
# User: RepCloudTX, Index: 49, isDem? False
# |████████████████████████████████████████| 270/270 [100%] in 2.3s (117.18/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 5166
# New Dem Tweets Stored: 5436
# User: WhipClyburn, Index: 50, isDem? True
# |⚠︎                                       | (!) 0/270 [0%] in 0.1s (0.00/s)
# USER NOT FOUND!
# User: Rep_Clyde, Index: 51, isDem? False
# |████████████████████████████████████████| 270/270 [100%] in 1.7s (163.94/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 5436
# New Dem Tweets Stored: 5706
# User: RepCohen, Index: 52, isDem? True
# |████████████████████████████████████████| 270/270 [100%] in 1.8s (146.28/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 6874
# New Dem Tweets Stored: 7144
# User: TomColeOK04, Index: 53, isDem? False
# |████████████████████████████████████████| 270/270 [100%] in 1.3s (199.22/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 5706
# New Dem Tweets Stored: 5976
# User: RepMikeCollins, Index: 54, isDem? False
# on 147: [Stopped!] Found 147 tweets for specifed term!
# |█████████████████████▊⚠︎                 | (!) 147/270 [54%] in 0.6s (237.78/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 5976
# New Dem Tweets Stored: 6123
# User: RepJamesComer, Index: 55, isDem? False
# |████████████████████████████████████████| 270/270 [100%] in 2.6s (102.16/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 6123
# New Dem Tweets Stored: 6393
# User: GerryConnolly, Index: 56, isDem? True
# |████████████████████████████████████████| 270/270 [100%] in 1.8s (151.76/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 7144
# New Dem Tweets Stored: 7414
# User: RepLouCorrea, Index: 57, isDem? True
# |████████████████████████████████████████| 270/270 [100%] in 1.3s (209.55/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 7414
# New Dem Tweets Stored: 7684
# User: RepJimCosta, Index: 58, isDem? True
# |████████████████████████████████████████| 270/270 [100%] in 1.2s (206.50/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 7684
# New Dem Tweets Stored: 7954
# User: RepJoeCourtney, Index: 59, isDem? True
# |████████████████████████████████████████| 270/270 [100%] in 1.4s (195.81/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 7954
# New Dem Tweets Stored: 8224
# User: RepAngieCraig, Index: 60, isDem? True
# |████████████████████████████████████████| 270/270 [100%] in 1.3s (222.94/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 8224
# New Dem Tweets Stored: 8494
# User: RepEliCrane, Index: 61, isDem? True
# on 65: [Stopped!] Found 65 tweets for specifed term!
# |█████████▋⚠︎                             | (!) 65/270 [24%] in 0.7s (101.27/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 8494
# New Dem Tweets Stored: 8559
# User: RepRickCrawford, Index: 62, isDem? False
# |████████████████████████████████████████| 270/270 [100%] in 2.2s (124.94/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 6393
# New Dem Tweets Stored: 6663
# User: RepDanCrenshaw, Index: 63, isDem? False
# |████████████████████████████████████████| 270/270 [100%] in 1.8s (150.63/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 6663
# New Dem Tweets Stored: 6933
# User: RepJasmine, Index: 64, isDem? True
# on 176: [Stopped!] Found 176 tweets for specifed term!
# |██████████████████████████▏⚠︎            | (!) 176/270 [65%] in 0.9s (184.11/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 8559
# New Dem Tweets Stored: 8735
# User: RepJasonCrow, Index: 65, isDem? True
# |████████████████████████████████████████| 270/270 [100%] in 1.2s (217.82/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 8735
# New Dem Tweets Stored: 9005
# User: RepCuellar, Index: 66, isDem? True
# |████████████████████████████████████████| 270/270 [100%] in 1.3s (184.67/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 9005
# New Dem Tweets Stored: 9275
# User: RepJohnCurtis, Index: 67, isDem? False
# |████████████████████████████████████████| 270/270 [100%] in 1.7s (159.00/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 6933
# New Dem Tweets Stored: 7203
# User: RepDavids, Index: 68, isDem? True
# |████████████████████████████████████████| 270/270 [100%] in 1.5s (176.09/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 9275
# New Dem Tweets Stored: 9545
# User: WarrenDavidson, Index: 69, isDem? False
# |████████████████████████████████████████| 270/270 [100%] in 2.4s (103.55/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 7203
# New Dem Tweets Stored: 7473
# User: RepDannyDavis, Index: 70, isDem? True
# |████████████████████████████████████████| 270/270 [100%] in 1.9s (152.07/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 9545
# New Dem Tweets Stored: 9815
# User: RodneyDavis, Index: 71, isDem? False
# |████████████████████████████████████████| 270/270 [100%] in 2.5s (98.43/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 7473
# New Dem Tweets Stored: 7743
# User: RepMonicaDLC, Index: 72, isDem? False
# on 53: [Stopped!] Found 53 tweets for specifed term!
# |███████▉⚠︎                               | (!) 53/270 [20%] in 0.5s (119.10/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 7743
# New Dem Tweets Stored: 7796
# User: RepDean, Index: 73, isDem? True
# |████████████████████████████████████████| 270/270 [100%] in 1.9s (130.55/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 9815
# New Dem Tweets Stored: 10085
# User: RepDianaDeGette, Index: 74, isDem? True
# |████████████████████████████████████████| 270/270 [100%] in 1.1s (240.20/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 10085
# New Dem Tweets Stored: 10355
# User: rosadelauro, Index: 75, isDem? True
# |████████████████████████████████████████| 270/270 [100%] in 1.9s (144.56/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 10355
# New Dem Tweets Stored: 10625
# User: RepDelBene, Index: 76, isDem? True
# |████████████████████████████████████████| 270/270 [100%] in 1.5s (171.75/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 10625
# New Dem Tweets Stored: 10895
# User: RepDeluzio, Index: 77, isDem? True
# on 142: [Stopped!] Found 142 tweets for specifed term!
# |█████████████████████⚠︎                  | (!) 142/270 [53%] in 0.8s (193.09/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 10895
# New Dem Tweets Stored: 11037
# User: RepDeSaulnier, Index: 78, isDem? True
# |████████████████████████████████████████| 270/270 [100%] in 1.5s (192.81/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 11037
# New Dem Tweets Stored: 11307
# User: DesJarlaisTN04, Index: 79, isDem? False
# |████████████████████████████████████████| 270/270 [100%] in 1.4s (177.75/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 7796
# New Dem Tweets Stored: 8066
# User: RepDesposito, Index: 80, isDem? False
# on 120: [Stopped!] Found 120 tweets for specifed term!
# |█████████████████▊⚠︎                     | (!) 120/270 [44%] in 0.8s (151.88/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 8066
# New Dem Tweets Stored: 8186
# User: MarioDB, Index: 81, isDem? False
# |████████████████████████████████████████| 270/270 [100%] in 1.9s (147.32/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 8186
# New Dem Tweets Stored: 8456
# User: RepDebDingell, Index: 82, isDem? True
# |████████████████████████████████████████| 270/270 [100%] in 1.3s (208.01/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 11307
# New Dem Tweets Stored: 11577
# User: RepLloydDoggett, Index: 83, isDem? True
# |████████████████████████████████████████| 270/270 [100%] in 1.3s (187.70/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 11577
# New Dem Tweets Stored: 11847
# User: RepDonaldsPress, Index: 84, isDem? False
# |████████████████████████████████████████| 270/270 [100%] in 1.3s (190.32/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 8456
# New Dem Tweets Stored: 8726
# User: RepJeffDuncan, Index: 85, isDem? False
# |████████████████████████████████████████| 270/270 [100%] in 1.6s (154.70/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 8726
# New Dem Tweets Stored: 8996
# User: DrNealDunnFL2, Index: 86, isDem? False
# |████████████████████████████████████████| 270/270 [100%] in 2.2s (120.40/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 8996
# New Dem Tweets Stored: 9266
# User: RepEdwards, Index: 87, isDem? False
# on 51: [Stopped!] Found 51 tweets for specifed term!
# |███████▌⚠︎                               | (!) 51/270 [19%] in 0.4s (152.44/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 9266
# New Dem Tweets Stored: 9317
# User: RepEllzey, Index: 88, isDem? False
# on 180: [Stopped!] Found 180 tweets for specifed term!
# |██████████████████████████▋⚠︎            | (!) 180/270 [67%] in 1.0s (196.67/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 9317
# New Dem Tweets Stored: 9497
# User: RepTomEmmer, Index: 89, isDem? False
# |⚠︎                                       | (!) 0/270 [0%] in 0.1s (0.00/s)
# USER NOT FOUND!
# User: RepEscobar, Index: 90, isDem? True
# |████████████████████████████████████████| 270/270 [100%] in 1.5s (185.32/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 11847
# New Dem Tweets Stored: 12117
# User: RepAnnaEshoo, Index: 91, isDem? True
# |████████████████████████████████████████| 270/270 [100%] in 2.1s (127.34/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 12117
# New Dem Tweets Stored: 12387
# User: RepEspaillat, Index: 92, isDem? True
# |████████████████████████████████████████| 270/270 [100%] in 1.8s (140.48/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 12387
# New Dem Tweets Stored: 12657
# User: RepRonEstes, Index: 93, isDem? False
# |████████████████████████████████████████| 270/270 [100%] in 1.2s (231.41/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 9497
# New Dem Tweets Stored: 9767
# User: RepDwightEvans, Index: 94, isDem? True
# |████████████████████████████████████████| 270/270 [100%] in 4.8s (56.25/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 12657
# New Dem Tweets Stored: 12927
# User: RepEzell, Index: 95, isDem? False
# on 71: [Stopped!] Found 71 tweets for specifed term!
# |██████████▌⚠︎                            | (!) 71/270 [26%] in 0.6s (130.02/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 9767
# New Dem Tweets Stored: 9838
# User: RepPatFallon, Index: 96, isDem? False
# |████████████████████████████████████████| 270/270 [100%] in 1.4s (190.73/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 9838
# New Dem Tweets Stored: 10108
# User: RepFeenstra, Index: 97, isDem? False
# |████████████████████████████████████████| 270/270 [100%] in 1.8s (138.89/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 10108
# New Dem Tweets Stored: 10378
# User: RepDrewFerguson, Index: 98, isDem? False
# |████████████████████████████████████████| 270/270 [100%] in 1.4s (178.48/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 10378
# New Dem Tweets Stored: 10648
# User: repfinstad, Index: 99, isDem? False
# on 188: [Stopped!] Found 188 tweets for specifed term!
# |███████████████████████████▉⚠︎           | (!) 188/270 [70%] in 1.1s (169.20/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 10648
# New Dem Tweets Stored: 10836
# User: RepFischbach, Index: 100, isDem? False
# |████████████████████████████████████████| 270/270 [100%] in 1.2s (226.87/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 10836
# New Dem Tweets Stored: 11106
# User: RepFitzgerald, Index: 101, isDem? False
# |████████████████████████████████████████| 270/270 [100%] in 1.2s (192.69/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 11106
# New Dem Tweets Stored: 11376
# User: RepBrianFitz, Index: 102, isDem? False
# |████████████████████████████████████████| 270/270 [100%] in 1.5s (179.84/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 11376
# New Dem Tweets Stored: 11646
# User: RepChuck, Index: 103, isDem? False
# |████████████████████████████████████████| 270/270 [100%] in 1.7s (164.87/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 11646
# New Dem Tweets Stored: 11916
# User: RepFletcher, Index: 104, isDem? True
# |████████████████████████████████████████| 270/270 [100%] in 1.0s (252.84/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 12927
# New Dem Tweets Stored: 13197
# User: USRepMikeFlood, Index: 105, isDem? False
# |████████████████████████████████████████| 270/270 [100%] in 1.5s (169.86/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 11916
# New Dem Tweets Stored: 12186
# User: RepBillFoster, Index: 106, isDem? True
# |████████████████████████████████████████| 270/270 [100%] in 1.3s (204.23/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 13197
# New Dem Tweets Stored: 13467
# User: ValerieFoushee, Index: 107, isDem? True
# on 43: [Stopped!] Found 43 tweets for specifed term!
# |██████▍⚠︎                                | (!) 43/270 [16%] in 0.4s (131.50/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 13467
# New Dem Tweets Stored: 13510
# User: virginiafoxx, Index: 108, isDem? False
# |████████████████████████████████████████| 270/270 [100%] in 2.4s (116.48/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 12186
# New Dem Tweets Stored: 12456
# User: RepLoisFrankel, Index: 109, isDem? True
# |████████████████████████████████████████| 270/270 [100%] in 1.8s (145.08/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 13510
# New Dem Tweets Stored: 13780
# User: RepFranklin, Index: 110, isDem? False
# |████████████████████████████████████████| 270/270 [100%] in 1.4s (184.90/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 12456
# New Dem Tweets Stored: 12726
# User: RepMaxwellFrost, Index: 111, isDem? True
# on 63: [Stopped!] Found 63 tweets for specifed term!
# |█████████▍⚠︎                             | (!) 63/270 [23%] in 0.7s (97.83/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 13780
# New Dem Tweets Stored: 13843
# User: RepRussellFry, Index: 112, isDem? False
# on 96: [Stopped!] Found 96 tweets for specifed term!
# |██████████████▎⚠︎                        | (!) 96/270 [36%] in 0.6s (174.28/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 12726
# New Dem Tweets Stored: 12822
# User: RepRussFulcher, Index: 113, isDem? False
# |████████████████████████████████████████| 270/270 [100%] in 1.0s (260.64/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 12822
# New Dem Tweets Stored: 13092
# User: RepMattGaetz, Index: 114, isDem? False
# |████████████████████████████████████████| 270/270 [100%] in 1.9s (139.61/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 13092
# New Dem Tweets Stored: 13362
# User: RepGallagher, Index: 115, isDem? False
# |████████████████████████████████████████| 270/270 [100%] in 1.5s (182.83/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 13362
# New Dem Tweets Stored: 13632
# User: RepRubenGallego, Index: 116, isDem? True
# |████████████████████████████████████████| 270/270 [100%] in 1.5s (160.09/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 13843
# New Dem Tweets Stored: 14113
# User: RepGaramendi, Index: 117, isDem? True
# |████████████████████████████████████████| 270/270 [100%] in 1.8s (146.34/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 14113
# New Dem Tweets Stored: 14383
# User: RepGarbarino, Index: 118, isDem? False
# |████████████████████████████████████████| 270/270 [100%] in 1.6s (152.08/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 13632
# New Dem Tweets Stored: 13902
# User: RepMikeGarcia, Index: 119, isDem? False
# |████████████████████████████████████████| 270/270 [100%] in 1.3s (191.97/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 13902
# New Dem Tweets Stored: 14172
# User: RepRobertGarcia, Index: 120, isDem? True
# on 128: [Stopped!] Found 128 tweets for specifed term!
# |███████████████████⚠︎                    | (!) 128/270 [47%] in 1.2s (117.13/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 14383
# New Dem Tweets Stored: 14511
# User: RepSylviaGarcia, Index: 121, isDem? True
# |████████████████████████████████████████| 270/270 [100%] in 1.2s (198.92/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 14511
# New Dem Tweets Stored: 14781
# User: RepChuyGarcia, Index: 122, isDem? True
# |████████████████████████████████████████| 270/270 [100%] in 1.8s (154.07/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 14781
# New Dem Tweets Stored: 15051
# User: RepCarlos, Index: 123, isDem? False
# |████████████████████████████████████████| 270/270 [100%] in 1.2s (199.62/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 14172
# New Dem Tweets Stored: 14442
# User: RepGolden, Index: 124, isDem? True
# |████████████████████████████████████████| 270/270 [100%] in 1.5s (180.43/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 15051
# New Dem Tweets Stored: 15321
# User: RepDanGoldman, Index: 125, isDem? True
# on 128: [Stopped!] Found 128 tweets for specifed term!
# |███████████████████⚠︎                    | (!) 128/270 [47%] in 0.7s (173.68/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 15321
# New Dem Tweets Stored: 15449
# User: RepJimmyGomez, Index: 126, isDem? True
# |████████████████████████████████████████| 270/270 [100%] in 1.9s (136.16/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 15449
# New Dem Tweets Stored: 15719
# User: RepTonyGonzales, Index: 127, isDem? False
# |████████████████████████████████████████| 270/270 [100%] in 1.2s (212.43/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 14442
# New Dem Tweets Stored: 14712
# User: RepGonzalez, Index: 128, isDem? True
# |████████████████████████████████████████| 270/270 [100%] in 1.5s (174.11/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 15719
# New Dem Tweets Stored: 15989
# User: RepJenniffer, Index: 129, isDem? False
# |████████████████████████████████████████| 270/270 [100%] in 1.4s (182.24/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 14712
# New Dem Tweets Stored: 14982
# User: RepBobGood, Index: 130, isDem? False
# |████████████████████████████████████████| 270/270 [100%] in 2.4s (98.94/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 14982
# New Dem Tweets Stored: 15252
# User: o official, Index: 131, isDem? False
# |⚠︎                                       | (!) 0/270 [0%] in 0.1s (0.00/s)
# USER NOT FOUND!
# User: RepGosar, Index: 132, isDem? False
# |████████████████████████████████████████| 270/270 [100%] in 1.7s (164.69/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 15252
# New Dem Tweets Stored: 15522
# User: RepJoshG, Index: 133, isDem? True
# |████████████████████████████████████████| 270/270 [100%] in 1.6s (157.11/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 15989
# New Dem Tweets Stored: 16259
# User: RepKayGranger, Index: 134, isDem? False
# |████████████████████████████████████████| 270/270 [100%] in 1.2s (209.41/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 15522
# New Dem Tweets Stored: 15792
# User: RepGarretGraves, Index: 135, isDem? False
# |████████████████████████████████████████| 270/270 [100%] in 1.9s (148.49/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 15792
# New Dem Tweets Stored: 16062
# User: RepSamGraves, Index: 136, isDem? False
# |████████████████████████████████████████| 270/270 [100%] in 1.1s (244.95/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 16062
# New Dem Tweets Stored: 16332
# User: RepMarkGreen, Index: 137, isDem? False
# |████████████████████████████████████████| 270/270 [100%] in 1.3s (192.81/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 16332
# New Dem Tweets Stored: 16602
# User: RepAlGreen, Index: 138, isDem? True
# |████████████████████████████████████████| 270/270 [100%] in 1.4s (177.20/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 16259
# New Dem Tweets Stored: 16529
# User: RepMTG, Index: 139, isDem? False
# |████████████████████████████████████████| 270/270 [100%] in 1.7s (140.55/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 16602
# New Dem Tweets Stored: 16872
# User: RepMGriffith, Index: 140, isDem? False
# |████████████████████████████████████████| 270/270 [100%] in 1.0s (252.72/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 16872
# New Dem Tweets Stored: 17142
# User: RepRaulGrijalva, Index: 141, isDem? True
# |████████████████████████████████████████| 270/270 [100%] in 2.3s (121.29/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 16529
# New Dem Tweets Stored: 16799
# User: RepGrothman, Index: 142, isDem? False
# |████████████████████████████████████████| 270/270 [100%] in 1.9s (144.37/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 17142
# New Dem Tweets Stored: 17412
# User: RepMichaelGuest, Index: 143, isDem? False
# |████████████████████████████████████████| 270/270 [100%] in 1.3s (206.54/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 17412
# New Dem Tweets Stored: 17682
# User: RepGuthrie, Index: 144, isDem? False
# |████████████████████████████████████████| 270/270 [100%] in 1.1s (216.03/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 17682
# New Dem Tweets Stored: 17952
# User: RepHageman, Index: 145, isDem? False
# on 56: [Stopped!] Found 56 tweets for specifed term!
# |████████▎⚠︎                              | (!) 56/270 [21%] in 0.5s (125.71/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 17952
# New Dem Tweets Stored: 18008
# User: RepJoshHarder, Index: 146, isDem? True
# |████████████████████████████████████████| 270/270 [100%] in 1.0s (267.65/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 16799
# New Dem Tweets Stored: 17069
# User: RepAndyHarrisMD, Index: 147, isDem? False
# |████████████████████████████████████████| 270/270 [100%] in 1.8s (152.86/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 18008
# New Dem Tweets Stored: 18278
# User: RepHarshbarger, Index: 148, isDem? False
# |████████████████████████████████████████| 270/270 [100%] in 1.3s (189.60/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 18278
# New Dem Tweets Stored: 18548
# User: RepJahanaHayes, Index: 149, isDem? True
# |████████████████████████████████████████| 270/270 [100%] in 1.0s (234.45/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 17069
# New Dem Tweets Stored: 17339
# User: repkevinhern, Index: 150, isDem? False
# |████████████████████████████████████████| 270/270 [100%] in 1.9s (133.55/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 18548
# New Dem Tweets Stored: 18818
# User: RepClayHiggins, Index: 151, isDem? False
# |████████████████████████████████████████| 270/270 [100%] in 1.5s (181.64/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 18818
# New Dem Tweets Stored: 19088
# User: RepBrianHiggins, Index: 152, isDem? True
# |████████████████████████████████████████| 270/270 [100%] in 1.4s (190.69/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 17339
# New Dem Tweets Stored: 17609
# User: RepFrenchHill, Index: 153, isDem? False
# |████████████████████████████████████████| 270/270 [100%] in 1.6s (170.88/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 19088
# New Dem Tweets Stored: 19358
# User: RepAshleyHinson, Index: 154, isDem? False
# |████████████████████████████████████████| 270/270 [100%] in 1.5s (180.04/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 19358
# New Dem Tweets Stored: 19628
# User: RepHorsford, Index: 155, isDem? True
# |████████████████████████████████████████| 270/270 [100%] in 1.1s (240.44/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 17609
# New Dem Tweets Stored: 17879
# User: RepHouchin, Index: 156, isDem? False
# on 70: [Stopped!] Found 70 tweets for specifed term!
# |██████████▍⚠︎                            | (!) 70/270 [26%] in 0.4s (170.59/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 19628
# New Dem Tweets Stored: 19698
# User: RepHoulahan, Index: 157, isDem? True
# |████████████████████████████████████████| 270/270 [100%] in 1.6s (172.93/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 17879
# New Dem Tweets Stored: 18149
# User: RepStenyHoyer, Index: 158, isDem? True
# |████████████████████████████████████████| 270/270 [100%] in 1.0s (226.32/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 18149
# New Dem Tweets Stored: 18419
# User: repvalhoyle, Index: 159, isDem? True
# on 33: [Stopped!] Found 33 tweets for specifed term!
# |████▉⚠︎                                  | (!) 33/270 [12%] in 0.4s (96.44/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 18419
# New Dem Tweets Stored: 18452
# User: RepRichHudson, Index: 160, isDem? False
# |████████████████████████████████████████| 270/270 [100%] in 1.5s (176.83/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 19698
# New Dem Tweets Stored: 19968
# User: RepHuffman, Index: 161, isDem? True
# |████████████████████████████████████████| 270/270 [100%] in 1.6s (165.67/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 18452
# New Dem Tweets Stored: 18722
# User: RepHuizenga, Index: 162, isDem? False
# |████████████████████████████████████████| 270/270 [100%] in 3.0s (88.88/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 19968
# New Dem Tweets Stored: 20238
# User: RepWesleyHunt, Index: 163, isDem? False
# on 132: [Stopped!] Found 132 tweets for specifed term!
# |███████████████████▌⚠︎                   | (!) 132/270 [49%] in 1.2s (117.82/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 20238
# New Dem Tweets Stored: 20370
# User: repdarrellissa, Index: 164, isDem? False
# |████████████████████████████████████████| 270/270 [100%] in 1.0s (292.68/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 20370
# New Dem Tweets Stored: 20640
# User: RepGlennIvey, Index: 165, isDem? True
# on 95: [Stopped!] Found 95 tweets for specifed term!
# |██████████████▏⚠︎                        | (!) 95/270 [35%] in 0.7s (138.79/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 18722
# New Dem Tweets Stored: 18817
# User: rep_jackson, Index: 166, isDem? True
# on 31: [Stopped!] Found 31 tweets for specifed term!
# |████▋⚠︎                                  | (!) 31/270 [11%] in 0.4s (94.46/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 18817
# New Dem Tweets Stored: 18848
# User: RepJeffJackson, Index: 167, isDem? True
# on 2: [Stopped!] Found 2 tweets for specifed term!
# |▎⚠︎                                      | (!) 2/270 [1%] in 0.3s (8.83/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 18848
# New Dem Tweets Stored: 18850
# User: RepRonnyJackson, Index: 168, isDem? False
# |████████████████████████████████████████| 270/270 [100%] in 1.2s (223.36/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 20640
# New Dem Tweets Stored: 20910
# User: JacksonLeeTX18, Index: 169, isDem? True
# |████████████████████████████████████████| 270/270 [100%] in 2.2s (124.29/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 18850
# New Dem Tweets Stored: 19120
# User: RepSaraJacobs, Index: 170, isDem? True
# |████████████████████████████████████████| 270/270 [100%] in 1.1s (230.12/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 19120
# New Dem Tweets Stored: 19390
# User: RepJayapal, Index: 171, isDem? True
# |████████████████████████████████████████| 270/270 [100%] in 1.6s (173.32/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 19390
# New Dem Tweets Stored: 19660
# User: RepJeffries, Index: 172, isDem? True
# |████████████████████████████████████████| 270/270 [100%] in 1.8s (148.97/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 19660
# New Dem Tweets Stored: 19930
# User: RepHankJohnson, Index: 173, isDem? True
# |████████████████████████████████████████| 270/270 [100%] in 1.7s (148.60/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 19930
# New Dem Tweets Stored: 20200
# User: RepMikeJohnson, Index: 174, isDem? False
# |████████████████████████████████████████| 270/270 [100%] in 1.9s (131.47/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 20910
# New Dem Tweets Stored: 21180
# User: RepBillJohnson, Index: 175, isDem? False
# |████████████████████████████████████████| 270/270 [100%] in 1.5s (173.39/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 21180
# New Dem Tweets Stored: 21450
# User: RepDustyJohnson, Index: 176, isDem? False
# |████████████████████████████████████████| 270/270 [100%] in 2.0s (128.55/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 21450
# New Dem Tweets Stored: 21720
# User: Jim_Jordan, Index: 177, isDem? False
# |████████████████████████████████████████| 270/270 [100%] in 1.8s (156.78/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 21720
# New Dem Tweets Stored: 21990
# User: RepDaveJoyce, Index: 178, isDem? False
# |████████████████████████████████████████| 270/270 [100%] in 1.3s (184.67/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 21990
# New Dem Tweets Stored: 22260
# User: RepJohnJoyce, Index: 179, isDem? False
# |████████████████████████████████████████| 270/270 [100%] in 1.1s (244.93/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 22260
# New Dem Tweets Stored: 22530
# User: RepKamlagerDove, Index: 180, isDem? True
# on 52: [Stopped!] Found 52 tweets for specifed term!
# |███████▊⚠︎                               | (!) 52/270 [19%] in 0.3s (162.24/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 20200
# ...
# on 110: [Stopped!] Found 110 tweets for specifed term!
# |████████████████▎⚠︎                      | (!) 110/270 [41%] in 0.6s (175.82/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 38289
# New Dem Tweets Stored: 38399
# User: RepKimSchrier, Index: 331, isDem? True
# |████████████████████████████████████████| 270/270 [100%] in 1.5s (166.99/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 38399
# New Dem Tweets Stored: 38669
# User: RepDavid, Index: 332, isDem? False
# |████████████████████████████████████████| 270/270 [100%] in 1.4s (181.59/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 38510
# New Dem Tweets Stored: 38780
# User: AustinScottGA08, Index: 333, isDem? False
# |████████████████████████████████████████| 270/270 [100%] in 1.4s (175.51/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 38780
# New Dem Tweets Stored: 39050
# User: repdavidscott, Index: 334, isDem? True
# |████████████████████████████████████████| 270/270 [100%] in 1.5s (188.87/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 38669
# New Dem Tweets Stored: 38939
# User: BobbyScott, Index: 335, isDem? True
# |████████████████████████████████████████| 270/270 [100%] in 1.8s (156.94/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 38939
# New Dem Tweets Stored: 39209
# User: PeteSessions, Index: 336, isDem? False
# |████████████████████████████████████████| 270/270 [100%] in 2.0s (135.02/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 39050
# New Dem Tweets Stored: 39320
# User: RepTerriSewell, Index: 337, isDem? True
# |████████████████████████████████████████| 270/270 [100%] in 1.4s (199.32/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 39209
# New Dem Tweets Stored: 39479
# User: BradSherman, Index: 338, isDem? True
# |████████████████████████████████████████| 270/270 [100%] in 1.6s (165.20/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 39479
# New Dem Tweets Stored: 39749
# User: RepSherrill, Index: 339, isDem? True
# |████████████████████████████████████████| 270/270 [100%] in 1.9s (138.95/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 39749
# New Dem Tweets Stored: 40019
# User: CongMikeSimpson, Index: 340, isDem? False
# |████████████████████████████████████████| 270/270 [100%] in 1.4s (185.60/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 39320
# New Dem Tweets Stored: 39590
# User: RepSlotkin, Index: 341, isDem? True
# |████████████████████████████████████████| 270/270 [100%] in 2.7s (99.11/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 40019
# New Dem Tweets Stored: 40289
# User: RepJasonSmith, Index: 342, isDem? False
# |████████████████████████████████████████| 270/270 [100%] in 1.2s (213.74/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 39590
# New Dem Tweets Stored: 39860
# User: RepAdrianSmith, Index: 343, isDem? False
# |████████████████████████████████████████| 270/270 [100%] in 1.5s (176.13/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 39860
# New Dem Tweets Stored: 40130
# User: RepAdamSmith, Index: 344, isDem? True
# |████████████████████████████████████████| 270/270 [100%] in 1.7s (156.39/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 40289
# New Dem Tweets Stored: 40559
# User: RepSmucker, Index: 345, isDem? False
# |████████████████████████████████████████| 270/270 [100%] in 1.1s (249.29/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 40130
# New Dem Tweets Stored: 40400
# User: RepEricSorensen, Index: 346, isDem? True
# on 75: [Stopped!] Found 75 tweets for specifed term!
# |███████████▏⚠︎                           | (!) 75/270 [28%] in 0.4s (233.88/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 40559
# New Dem Tweets Stored: 40634
# User: RepDarrenSoto, Index: 347, isDem? True
# |████████████████████████████████████████| 270/270 [100%] in 1.4s (194.44/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 40634
# New Dem Tweets Stored: 40904
# User: RepSpanberger, Index: 348, isDem? True
# |████████████████████████████████████████| 270/270 [100%] in 1.3s (182.10/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 40904
# New Dem Tweets Stored: 41174
# User: RepSpartz, Index: 349, isDem? False
# |████████████████████████████████████████| 270/270 [100%] in 1.2s (230.67/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 40400
# New Dem Tweets Stored: 40670
# User: Rep_Stansbury, Index: 350, isDem? True
# |████████████████████████████████████████| 270/270 [100%] in 1.6s (172.80/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 41174
# New Dem Tweets Stored: 41444
# User: RepGregStanton, Index: 351, isDem? True
# |████████████████████████████████████████| 270/270 [100%] in 1.3s (198.20/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 41444
# New Dem Tweets Stored: 41714
# User: RepPeteStauber, Index: 352, isDem? False
# |████████████████████████████████████████| 270/270 [100%] in 1.3s (187.94/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 40670
# New Dem Tweets Stored: 40940
# User: RepSteel, Index: 353, isDem? False
# |████████████████████████████████████████| 270/270 [100%] in 1.3s (181.00/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 40940
# New Dem Tweets Stored: 41210
# User: RepStefanik, Index: 354, isDem? False
# |████████████████████████████████████████| 270/270 [100%] in 1.1s (244.26/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 41210
# New Dem Tweets Stored: 41480
# User: RepBryanSteil, Index: 355, isDem? False
# |████████████████████████████████████████| 270/270 [100%] in 1.7s (155.91/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 41480
# New Dem Tweets Stored: 41750
# User: RepGregSteube, Index: 356, isDem? False
# |████████████████████████████████████████| 270/270 [100%] in 1.4s (195.36/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 41750
# New Dem Tweets Stored: 42020
# User: RepHaleyStevens, Index: 357, isDem? True
# |████████████████████████████████████████| 270/270 [100%] in 1.1s (222.89/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 41714
# New Dem Tweets Stored: 41984
# User: RepChrisStewart, Index: 358, isDem? False
# |████████████████████████████████████████| 270/270 [100%] in 1.6s (172.35/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 42020
# New Dem Tweets Stored: 42290
# User: RepStricklandWA, Index: 359, isDem? True
# |████████████████████████████████████████| 270/270 [100%] in 1.6s (165.33/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 41984
# New Dem Tweets Stored: 42254
# User: RepDaleStrong, Index: 360, isDem? False
# on 252: [Stopped!] Found 252 tweets for specifed term!
# |█████████████████████████████████████▍⚠︎ | (!) 252/270 [93%] in 1.2s (220.37/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 42290
# New Dem Tweets Stored: 42542
# User: RepSwalwell, Index: 361, isDem? True
# |████████████████████████████████████████| 270/270 [100%] in 2.1s (129.29/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 42254
# New Dem Tweets Stored: 42524
# User: RepEmiliaSykes, Index: 362, isDem? True
# on 75: [Stopped!] Found 75 tweets for specifed term!
# |███████████▏⚠︎                           | (!) 75/270 [28%] in 0.4s (198.69/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 42524
# New Dem Tweets Stored: 42599
# User: RepMarkTakano, Index: 363, isDem? True
# |████████████████████████████████████████| 270/270 [100%] in 1.8s (133.98/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 42599
# New Dem Tweets Stored: 42869
# User: RepTenney, Index: 364, isDem? False
# |████████████████████████████████████████| 270/270 [100%] in 1.0s (246.40/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 42542
# New Dem Tweets Stored: 42812
# User: RepShriThanedar, Index: 365, isDem? True
# on 21: [Stopped!] Found 21 tweets for specifed term!
# |███▏⚠︎                                   | (!) 21/270 [8%] in 0.4s (64.58/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 42869
# New Dem Tweets Stored: 42890
# User: RepThompson, Index: 366, isDem? True
# |████████████████████████████████████████| 270/270 [100%] in 1.4s (207.59/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 42890
# New Dem Tweets Stored: 43160
# User: BennieGThompson, Index: 367, isDem? True
# |████████████████████████████████████████| 270/270 [100%] in 1.9s (137.86/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 43160
# New Dem Tweets Stored: 43430
# User: CongressmanGT, Index: 368, isDem? False
# |████████████████████████████████████████| 270/270 [100%] in 1.6s (173.16/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 42812
# New Dem Tweets Stored: 43082
# User: RepTiffany, Index: 369, isDem? False
# |████████████████████████████████████████| 270/270 [100%] in 1.6s (153.91/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 43082
# New Dem Tweets Stored: 43352
# User: RepTimmons, Index: 370, isDem? False
# |████████████████████████████████████████| 270/270 [100%] in 2.4s (114.71/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 43352
# New Dem Tweets Stored: 43622
# User: repdinatitus, Index: 371, isDem? True
# |████████████████████████████████████████| 270/270 [100%] in 1.3s (204.49/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 43430
# New Dem Tweets Stored: 43700
# User: RepRashida, Index: 372, isDem? True
# |████████████████████████████████████████| 270/270 [100%] in 1.2s (191.40/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 43700
# New Dem Tweets Stored: 43970
# User: RepJillTokuda, Index: 373, isDem? True
# on 60: [Stopped!] Found 60 tweets for specifed term!
# |████████▉⚠︎                              | (!) 60/270 [22%] in 0.5s (140.54/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 43970
# New Dem Tweets Stored: 44030
# User: RepPaulTonko, Index: 374, isDem? True
# |████████████████████████████████████████| 270/270 [100%] in 1.2s (206.17/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 44030
# New Dem Tweets Stored: 44300
# User: NormaJTorres, Index: 375, isDem? True
# |████████████████████████████████████████| 270/270 [100%] in 1.5s (174.11/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 44300
# New Dem Tweets Stored: 44570
# User: RepRitchie, Index: 376, isDem? True
# |████████████████████████████████████████| 270/270 [100%] in 1.4s (186.48/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 44570
# New Dem Tweets Stored: 44840
# User: RepLoriTrahan, Index: 377, isDem? True
# |████████████████████████████████████████| 270/270 [100%] in 1.2s (232.16/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 44840
# New Dem Tweets Stored: 45110
# User: RepDavidTrone, Index: 378, isDem? True
# |████████████████████████████████████████| 270/270 [100%] in 1.4s (191.38/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 45110
# New Dem Tweets Stored: 45380
# User: RepMikeTurner, Index: 379, isDem? False
# |████████████████████████████████████████| 270/270 [100%] in 2.0s (142.71/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 43622
# New Dem Tweets Stored: 43892
# User: RepUnderwood, Index: 380, isDem? True
# |████████████████████████████████████████| 270/270 [100%] in 1.2s (208.23/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 45380
# New Dem Tweets Stored: 45650
# User: RepDavidValadao, Index: 381, isDem? False
# |████████████████████████████████████████| 270/270 [100%] in 1.4s (194.92/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 43892
# New Dem Tweets Stored: 44162
# User: Congressman_JVD, Index: 382, isDem? False
# |████████████████████████████████████████| 270/270 [100%] in 1.2s (214.53/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 44162
# New Dem Tweets Stored: 44432
# User: RepBethVanDuyne, Index: 383, isDem? False
# |████████████████████████████████████████| 270/270 [100%] in 2.0s (137.92/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 44432
# New Dem Tweets Stored: 44702
# User: RepVanOrden, Index: 384, isDem? False
# on 85: [Stopped!] Found 85 tweets for specifed term!
# |████████████▋⚠︎                          | (!) 85/270 [31%] in 0.5s (176.33/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 44702
# New Dem Tweets Stored: 44787
# User: RepJuanVargas, Index: 385, isDem? True
# |████████████████████████████████████████| 270/270 [100%] in 1.4s (195.24/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 45650
# New Dem Tweets Stored: 45920
# User: RepVeasey, Index: 386, isDem? True
# |████████████████████████████████████████| 270/270 [100%] in 1.5s (186.50/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 45920
# New Dem Tweets Stored: 46190
# User: NydiaVelazquez, Index: 387, isDem? True
# |████████████████████████████████████████| 270/270 [100%] in 1.7s (156.84/s)
# Inserting Tweets to MongoDB...
# Current # Dem Tweets Stored: 46190
# New Dem Tweets Stored: 46460
# User: RepAnnWagner, Index: 388, isDem? False
# |████████████████████████████████████████| 270/270 [100%] in 1.8s (150.10/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 44787
# New Dem Tweets Stored: 45057
# User: RepWalberg, Index: 389, isDem? False
# |████████████████████████████████████████| 270/270 [100%] in 1.2s (200.48/s)
# Inserting Tweets to MongoDB...
# Current # Rep Tweets Stored: 45057
# New Dem Tweets Stored: 45327

# %%
#----------------------------------------------

# Deleted accounts: ['RepKClark', 'WhipClyburn', 'RepTomEmmer', 'o official', 'RepKiggans', 'RepLuttrell_TX8', 'teammoulton', 'RepMullin']
missing_accounts = db.missing_accounts
print(deleted_users)
#missing_accounts.insert_many({usr: user_map[usr] for usr in missing_accounts})

# Get total number of tweets

# Save tweet text into republican and democratic lists


celeb_tweets = []
# Out:
# ['RepKClark', 'WhipClyburn', 'RepTomEmmer', 'o official', 'RepKiggans', 'RepLuttrell_TX8', 'teammoulton', 'RepMullin']
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-e93827495478> in <module>
#       4 missing_accounts = db.missing_accounts
#       5 print(deleted_users)
# ----> 6 missing_accounts.insert_many({usr: user_map[usr] for usr in missing_accounts})
#       7
#       8 # Get total number of tweets
#
# TypeError: 'Collection' object is not iterable
